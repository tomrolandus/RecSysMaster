# %% [markdown]
# <small><i>Updated February 2019 - This notebook was created by [Santi Seguí](https://ssegui.github.io/). </i></small>

# %% [markdown]
# <div class="alert alert-success" style = "border-radius:10px;border-width:3px;border-color:darkgreen;font-family:Verdana,sans-serif;font-size:16px;"><a class="anchor" id="what-is-a-recommender"></a><h3>Non-Personalized recommeder systems</h3><br></div>
#
# <br>
# <p>A non-personalized recommender system is one that makes the same recommendations for everyone. </p>
#
# The simplest example is a retailer that shows the ten (or some number) most popular products on their homepage. <br>
# Some examples: <br><br>
# IMDB: MOVIE RANKING
# ![alt IMDB](images/np1.png)
#
# ___
# Amazon: Top Recommendations
# ![alt Amazon](images/np2.png)
# ___
# Amazon: Product Association
# ![alt Amazon](images/np3.png)
# ___
# Reedit: News Recommendations
# ![alt Reedit](images/np4.png)
#
#
# <p><b>Several</b> cases but <b>two main</b> approaches
#
# 1. Aggregated opinion recommenders
# 2. Basic product association recommenders
# <br>
# <div class="alert alert-success" style = "border-radius:10px;border-width:3px;border-color:darkgreen;font-family:Verdana,sans-serif;font-size:16px;"><a class="anchor" id="what-is-a-recommender"></a><h3>Aggregated opinion recommenders</h3><br></div>
#
# Usually, the problem posed as a learning to rank problem. But what seems to be straighfowrard becomes a really complicated question: <b>How do you rank your rated items and which logic to use to display them?</b>
#
# In order to score/rank items we first have to <b>understand the business case</b>. Of course, several factors plays a role. For instance,
#
# * Which information do we have about the items? Bought / Seen / Rated / ...
# * From how many users do we have the info for a particular item
# * How old is that info?

# %% [markdown]
# ## EXAMPLE: Non-Personalised Recommender using MovieLens Dataset
# We will work with the well known MovieLens dataset (http://grouplens.org/datasets/movielens/). This dataset was initially constructed to support participants in the Netflix Prize. Today, we can find several versions of this dataset with different amout of data, from 100k samples version to 20m sample version. Although performance on bigger dataset is expected to be better, we will work with the smallest dataset: MovieLens 100K Dataset (ml-100k-zip). Working with this lite version has the benefit of less computational costs
#
# With a unix machine the dataset can be downloaded with the following code:

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /anaconda3/lib/python3.6/site-packages (3.2)

# %%
# !wget http://files.grouplens.org/datasets/movielens/ml-100k.zip 
# !unzip ml-1m.zip -d "data/"
# Out:
# /bin/sh: wget: command not found
# unzip:  cannot find or open ml-1m.zip, ml-1m.zip.zip or ml-1m.zip.ZIP.

# %% [markdown]
# If you are working with a windows machine, please go to the website and download the 100k version and extract it to the subdirectory named "data/ml-100k/"
#
# Once you have downloaded and unzipped the file into a directory, you can create a DataFrame with the following code:

# %%
#NETFLIX REAL 50.000.000 usuaris and 100.000 items
# %autosave 150
# %matplotlib inline
import pandas as pd
import numpy as np
import math
import matplotlib.pylab as plt

# Load Data set
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('data/ml-1m/users.dat', sep='::', names=u_cols)

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('data/ml-1m/ratings.dat', sep='::', names=r_cols)

# the movies file contains columns indicating the movie's genres
# let's only load the first three columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date']
movies = pd.read_csv('data/ml-1m/movies.dat', sep='::', names=m_cols, usecols=range(3), encoding='latin-1')

# Construcció del DataFrame
data = pd.merge(pd.merge(ratings, users), movies)
data = data[['user_id','title', 'movie_id','rating','release_date','sex','age']]


print("La BD has "+ str(data.shape[0]) +" ratings")
print("La BD has ", data.user_id.nunique()," users")
print("La BD has ", data.movie_id.nunique(), " movies")
data.head()
# Out:
# Autosaving every 150 seconds
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# La BD has 1000209 ratings
# La BD has  6040  users
# La BD has  3706  movies
#    user_id                                   title  movie_id  rating  \
# 0        1  One Flew Over the Cuckoo's Nest (1975)      1193       5
# 1        2  One Flew Over the Cuckoo's Nest (1975)      1193       5
# 2       12  One Flew Over the Cuckoo's Nest (1975)      1193       4
# 3       15  One Flew Over the Cuckoo's Nest (1975)      1193       4
# 4       17  One Flew Over the Cuckoo's Nest (1975)      1193       5
#
#   release_date  sex age
# 0        Drama    1   F
# 1        Drama   56   M
# 2        Drama   25   M
# 3        Drama   25   M
# 4        Drama   50   M

# %% [markdown]
# If you explore the dataset in detail, you will see that it consists of:
#
# 100,000 ratings from 943 users of 1682 movies. Ratings are from 1 to 5.
# Each user has rated at least 20 movies.
# Simple demographic info for the users (age, gender, occupation, zip)

# %% [markdown]
# ### 2.1 Top movies ranking.
# The simplest way to show the ranking is by using the mean rating.

# %%
mean_score = data.groupby(['title'])[['rating']].mean().rename(columns = {'rating': 'mean_rating'})
mean_score.sort_values(by='mean_rating',ascending=False).head(10)
# Out:
#                                            mean_rating
# title
# Ulysses (Ulisse) (1954)                            5.0
# Lured (1947)                                       5.0
# Follow the Bitch (1998)                            5.0
# Bittersweet Motel (2000)                           5.0
# Song of Freedom (1936)                             5.0
# One Little Indian (1973)                           5.0
# Smashing Time (1967)                               5.0
# Schlafes Bruder (Brother of Sleep) (1995)          5.0
# Gate of Heavenly Peace, The (1995)                 5.0
# Baby, The (1973)                                   5.0

# %% [markdown]
# <div class="alert alert-error" style = "border-radius:10px;border-width:3px;border-color:darkred;font-family:Verdana,sans-serif;font-size:14px;">
# What do you think about the output? </div><br>
# Now, let's show only ranking the mean rating but using only those movies with at least 20 ratings

# %%
size = data.groupby('title').size()
mean_score.loc[size>20].sort_values(by='mean_rating',ascending=False).head(10)
# Out:
#                                                     mean_rating
# title
# Sanjuro (1962)                                         4.608696
# Seven Samurai (The Magnificent Seven) (Shichini...     4.560510
# Shawshank Redemption, The (1994)                       4.554558
# Godfather, The (1972)                                  4.524966
# Close Shave, A (1995)                                  4.520548
# Usual Suspects, The (1995)                             4.517106
# Schindler's List (1993)                                4.510417
# Wrong Trousers, The (1993)                             4.507937
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)          4.491489
# Raiders of the Lost Ark (1981)                         4.477725

# %% [markdown]
# <div class="alert alert-error" style = "border-radius:10px;border-width:3px;border-color:darkred;font-family:Verdana,sans-serif;font-size:14px;">
# Any other idea?<br>
# How can you improve it?</div>

# %% [markdown]
# ### There is other measures like the <b>Damped Means</b>.
#
#
# * <b>Problem:</b> There is low conficende with few ratings
# * <b>Solution:</b> Assume that, without evidence, everything is average.
#
# <br>
# $damped\_Means = \frac{\sum_u r_{u,i} + k \mu}{n +  k}$
# <br><br>$k$ controls the strength of the requiered evidence
#
# <br>

# %%
k = 10

mean_score_movies  = data.groupby('movie_id')[['rating']].mean().rename(columns = {'rating': 'mean_rating'}).reset_index()
sum_ratings_movie = data.groupby('movie_id')[['rating']].sum().rename(columns = {'rating': 'num_ratings'}).reset_index()
sum_ratings_movie['num_ratings_factor'] = sum_ratings_movie['num_ratings'] + k *(data['rating'].mean())

count_ratings = data.groupby('movie_id')[['rating']].count().rename(columns = {'rating': 'count_rating'}).reset_index()
count_ratings['count_rating_factor'] = count_ratings['count_rating'] + k

ratings_damped = pd.merge(sum_ratings_movie,
                         count_ratings[['movie_id','count_rating','count_rating_factor']],
                         on=['movie_id'],how='left')

ratings_damped['damped_mean']=ratings_damped['num_ratings_factor']/ratings_damped['count_rating_factor']

ratings_mean_damped=pd.merge(data[['title','movie_id']].drop_duplicates(),
                             ratings_damped[['movie_id','damped_mean']],
                             on=['movie_id'],how='left')

ratings_mean_damped = ratings_mean_damped.sort_values(by='damped_mean', ascending=False)
ratings_mean_damped.head()
# Out:
#                                                   title  movie_id  damped_mean
# 167                    Shawshank Redemption, The (1994)       318     4.550208
# 1092  Seven Samurai (The Magnificent Seven) (Shichin...      2019     4.545166
# 669                               Godfather, The (1972)       858     4.520741
# 259                          Usual Suspects, The (1995)        50     4.511888
# 29                                Close Shave, A (1995)       745     4.506470

# %% [markdown]
# ## Ranking Cosiderations
#
# + Confidence
#  - How confident are we that this item is good?
#
# + Risk tolerance
#  - High-risk, high-reward
#  - Conservative recommendations+
#
# + Domain and business considerations
#  - Age
#  - System goals

# %% [markdown]
# ANOTHER EXAMPLE DOMAIN CONSTRAINT: TIME
#
# <p><b>REDDIT:</b> Old stories are not interesting even though they might have a high net upvotes score! How does Reddit deal with this?</p>
# <br>
# $$log_{10}max( 1,| U -D | ) +  \frac{sign(U-D)*t_{post}}{45000} $$
# <br>
# where $U$ is the number of upvotes and $D$ is the number of downvotes.
# * In Reddit, time and votes were treated independently.
# * The Log term has a damping effect for votes. The idea is that votes 11 to 100 should have the same influence as votes 1 to 10. Obviously, a post with 1000 votes should be better than a post with 1 vote, but is a post with 2000 votes much better than the 1000 votes? The log decreases marginal values for later votes.
# * The sign(U-D) is useful to bury any negative items (as Reddit wants only to show the popular ones!)
#
# <p><b>HACKERS NEWS:</b> </p>
#
# $$ \frac{(U - D  +1)^\alpha}{(t_{now} - t_{post})^\gamma} P $$
#
# * Numerator is related to popularity
# * Denominator is realted to the age factor with a gravity effect with the $\gamma$ parameter
# * $P$ is a penalty term for each new
#
# ![alt hackers](images/hackers.png)
#
#
# <h3>It was really famous and then it become to getting worse.</h3>
# ![alt ![alt IMDB](images/zagat.png)
# ](images/zagat.png)

# %%
# Why?

# %% [markdown]
# <div class="alert alert-success" style = "border-radius:10px;border-width:3px;border-color:darkgreen;font-family:Verdana,sans-serif;font-size:16px;"><a class="anchor" id="what-is-a-recommender"></a><h3>Basic product association recommenders
# </h3><br> People who buy X also buy Y. </div>

# %%
#Let's read a dataset which contains several market baskets lists

# read data/grocieries.csv
def union(a, b):
    """ return the union of two lists """
    return list(set(a) | set(b))

market_data = []
cont = 0
items = []
with open("data/groceries.csv") as f:
    for l in f:
        market_data.append(l.rstrip().split(','))
        items = union(items,l.rstrip().split(','))

print("Number of different items", len(items))
print("Number of rows ", len(market_data))


print("An example:", market_data[3])
# Out:
# Number of different items 171
# Number of rows  9835
# An example: ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads']

# %% [markdown]
# One of the most simple ways to found association between product could be obtained as follows: $$score(Y|X) = \frac{X \ and \ Y}{X}$$

# %%
# Which is the top associated product with "yogurt"?

# %%
def top_associated_products(product,N = 5):
    d = {}
    times = 0
    for l in market_data:
        if product in l:
            times = times + 1
            for i in l:
                if i != product: 
                    if(i in d):
                        d[i] += 1.0
                    else:
                        d[i] = 1.0

    for k in d:
        d[k] =   d[k] / times
    sorted_list=sorted(d.items(), key=lambda x: x[1],reverse=True)
    return sorted_list[:N]

# %%
s = top_associated_products('yogurt',N = 3)
print(s)
# Out:
# [('whole milk', 0.40160349854227406), ('other vegetables', 0.3112244897959184), ('rolls/buns', 0.24635568513119532)]

# %%
# Which is the top associated prouct with "rice"?
s = top_associated_products('rice',N = 3)
print(s)
# Out:
# [('whole milk', 0.6133333333333333), ('other vegetables', 0.52), ('root vegetables', 0.41333333333333333)]

# %%
# Which is the top associated prouct with "rum"?
s = top_associated_products('rum',N = 3)
print(s)
# Out:
# [('whole milk', 0.38636363636363635), ('other vegetables', 0.3409090909090909), ('tropical fruit', 0.20454545454545456)]

# %% [markdown]
# What happens? Is it a good measure? It has a problem with popular items...
# <br>
# Let's check this other formula:
# $$score(Y|X) = \frac{ \frac{X \ and \ Y}{X}} {  \frac{!X \ and \ Y}{!X} }  $$

# %%
from collections import defaultdict

def top_associated_products2(product,N = 5):
    d, d_not, d_yes = {}, {}, {}
    d = defaultdict(lambda: 0, d)
    d_not = defaultdict(lambda: 0, d_not)
    times, times_not = 0, 0
    for l in market_data:
        if product in l:
            times = times + 1
            for i in l:
                if i != product: 
                    if(i in d_yes):
                        d_yes[i] += 1.0
                    else:
                        d_yes[i] = 1.0
        else:
            times_not = times_not + 1
            for i in l:
                if(i in d_not):
                    d_not[i] += 1.0
                else:
                    d_not[i] = 1.0
                        
    for k in d_yes:
        if(d_not[k] == 0):
            d[k] = 0
        else:
            d[k] =  ( d_yes[k] *times_not) / (times * d_not[k])
    sorted_list=sorted(d.items(), key=lambda x: x[1],reverse=True)
    return sorted_list[:N]

# %%
s = top_associated_products2('yogurt',N = 3)
print(s)
# Out:
# [('kitchen utensil', 6.168367346938775), ('preservation products', 6.168367346938775), ('meat spreads', 4.626275510204081)]

# %%
# Which is the top associated prouct with "rice"?
s = top_associated_products2('rice',N = 3)
print(s)
# Out:
# [('decalcifier', 20.02051282051282), ('canned fruit', 18.590476190476192), ('organic products', 18.590476190476192)]

# %%
# Which is the top associated prouct with "rum"?
s = top_associated_products2('rum',N = 3)
print(s)
# Out:
# [('artif. sweetener', 14.834848484848484), ('specialty vegetables', 13.907670454545455), ('cooking chocolate', 9.271780303030303)]

# %% [markdown]
# #### Let's check this last formula:
# $$ score(Y|X) = \frac{P(X \ and \ Y)}{P(X)P(Y) }   $$

# %%
def top_associated_products3(product,N = 5):
    d , times = {}, {}
    d = defaultdict(lambda: 0, d)
    times = defaultdict(lambda: 0, times)
    for l in market_data:
        for item in l:
            if item in times: #already exist
                times[item] += 1
            else:
                times[item] =1
        if product in l:
            for i in l:
                if i != product: 
                    if(i in d):
                        d[i] += 1.0
                    else:
                        d[i] = 1.0
                        
    for k in d:
        d[k] =  ( d[k] /len(market_data) ) / ((times[k]/len(market_data)) * times[product] /(len(market_data)))
        
    sorted_list=sorted(d.items(), key=lambda x: x[1],reverse=True)
    return sorted_list[:N]

# %%
s = top_associated_products3('yogurt',N = 3)
print(s)
# Out:
# [('baby food', 7.168367346938775), ('kitchen utensil', 3.5841836734693877), ('preservation products', 3.5841836734693877)]

# %%
# Which is the top associated prouct with "rice"?
s = top_associated_products3('rice',N = 3)
print(s)
# Out:
# [('decalcifier', 17.484444444444446), ('canned fruit', 16.391666666666666), ('organic products', 16.391666666666666)]

# %%
# Which is the top associated prouct with "rice"?
s = top_associated_products3('rum',N = 3)
print(s)
# Out:
# [('artif. sweetener', 13.970170454545455), ('specialty vegetables', 13.148395721925132), ('cooking chocolate', 8.940909090909091)]

# %%
s = top_associated_products3('baby food',N = 3)
print(s)
# Out:
# [('finished products', 153.671875), ('soups', 146.7910447761194), ('cake bar', 75.65384615384615)]

# %% [markdown]
# ## APRIORI Algorithm
# Typically, association rules are considered interesting if they satisfy both a minimum support threshold and a minimum confidence threshold
#
# ![alt apriori](images/apriori.png)
#
# <b>Apriori principle</b>: Any subset of a frequent itemset must be frequent
#
# > Step 1: Find the frequent itemsset: the set of items that have minimum support.
# > -  A subset of a frequent itemset must also be a frequent itemset  i.e. if {1,2} is a frequent itemset, both {1} and {2} should be a frequent itemset
# > - Iteratively find frequent itemsets with cardinality from 1 to k (k-itemset)
#
# > Step 2: Use the frequent itemsets to generate association rules
#
# ![alt apriori2](images/apriori2.png)
#
# Reference :
# [Fast algorithms for mining association rules](http://www-cgi.cs.cmu.edu/afs/cs.cmu.edu/Web/People/ngm/15-721/summaries/12.pdf)

# %%
#adapted code from https://github.com/asaini/Apriori
import sys

from itertools import chain, combinations
from collections import defaultdict
from optparse import OptionParser


def subsets(arr):
    """ Returns non empty subsets of arr"""
    return chain(*[combinations(arr, i + 1) for i, a in enumerate(arr)])


def returnItemsWithMinSupport(itemSet, transactionList, minSupport, freqSet):
        """calculates the support for items in the itemSet and returns a subset
       of the itemSet each of whose elements satisfies the minimum support"""
        _itemSet = set()
        localSet = defaultdict(int)

        for item in itemSet:
                for transaction in transactionList:
                        if item.issubset(transaction):
                                freqSet[item] += 1
                                localSet[item] += 1

        for item, count in localSet.items():
                support = float(count)/len(transactionList)

                if support >= minSupport:
                        _itemSet.add(item)

        return _itemSet


def joinSet(itemSet, length):
        """Join a set with itself and returns the n-element itemsets"""
        return set([i.union(j) for i in itemSet for j in itemSet if len(i.union(j)) == length])


def getItemSetTransactionList(data_iterator):
    transactionList = list()
    itemSet = set()
    for record in data_iterator:
        transaction = frozenset(record)
        transactionList.append(transaction)
        for item in transaction:
            itemSet.add(frozenset([item]))              # Generate 1-itemSets
    return itemSet, transactionList


def runApriori(data_iter, minSupport, minConfidence):
    """
    run the apriori algorithm. data_iter is a record iterator
    Return both:
     - items (tuple, support)
     - rules ((pretuple, posttuple), confidence)
    """
    
    itemSet, transactionList = getItemSetTransactionList(data_iter)
    freqSet = defaultdict(int)
    largeSet = dict()
    # Global dictionary which stores (key=n-itemSets,value=support)
    # which satisfy minSupport

    assocRules = dict()
    # Dictionary which stores Association Rules
    
    oneCSet = returnItemsWithMinSupport(itemSet,
                                        transactionList,
                                        minSupport,
                                        freqSet)

    
    currentLSet = oneCSet
    k = 2
    while(currentLSet != set([])):
        largeSet[k-1] = currentLSet
        currentLSet = joinSet(currentLSet, k)
        currentCSet = returnItemsWithMinSupport(currentLSet,
                                                transactionList,
                                                minSupport,
                                                freqSet)
        currentLSet = currentCSet
        k = k + 1

    def getSupport(item):
            """local function which Returns the support of an item"""
            return float(freqSet[item])/len(transactionList)

    toRetItems = []
    for key, value in list(largeSet.items()):
        toRetItems.extend([(tuple(item), getSupport(item))
                           for item in value])

    toRetRules = []
    for key, value in list(largeSet.items())[1:]:
        for item in value:
            _subsets = map(frozenset, [x for x in subsets(item)])
            for element in _subsets:
                remain = item.difference(element)
                if len(remain) > 0:
                    confidence = getSupport(item)/getSupport(element)
                    if confidence >= minConfidence:
                        toRetRules.append(((tuple(element), tuple(remain)),
                                           confidence))
    return toRetItems, toRetRules


def printResults(items, rules):
    """prints the generated itemsets sorted by support and the confidence rules sorted by confidence"""
    for item, support in sorted(items, key = lambda x: float(x[1])):
        print("item: %s , %.3f" % (str(item), support))
    print("\n------------------------ RULES:")
    for rule, confidence in sorted(rules, key=lambda x: float(x[1])):
        pre, post = rule
        print("Rule: %s ==> %s , %.3f" % (str(pre), str(post), confidence))


def dataFromFile(fname):
        """Function which reads from the file and yields a generator"""
        file_iter = open(fname, 'r')
        for line in file_iter:
                line = line.strip().rstrip(',')                         # Remove trailing comma
                record = frozenset(line.split(','))
                yield record

# %%
inFile = dataFromFile('data/groceries.csv')
minSupport = 0.04
minConfidence = 0.4
items, rules =  runApriori(inFile, minSupport, minConfidence)
printResults(items, rules)
# Out:
# item: ('soda', 'whole milk') , 0.040
# item: ('white bread',) , 0.042
# item: ('tropical fruit', 'whole milk') , 0.042
# item: ('rolls/buns', 'other vegetables') , 0.043
# item: ('chicken',) , 0.043
# item: ('other vegetables', 'yogurt') , 0.043
# item: ('other vegetables', 'root vegetables') , 0.047
# item: ('frozen vegetables',) , 0.048
# item: ('whole milk', 'root vegetables') , 0.049
# item: ('chocolate',) , 0.050
# item: ('napkins',) , 0.052
# item: ('beef',) , 0.052
# item: ('curd',) , 0.053
# item: ('butter',) , 0.055
# item: ('whole milk', 'yogurt') , 0.056
# item: ('rolls/buns', 'whole milk') , 0.057
# item: ('pork',) , 0.058
# item: ('coffee',) , 0.058
# item: ('margarine',) , 0.059
# item: ('frankfurter',) , 0.059
# item: ('domestic eggs',) , 0.063
# item: ('brown bread',) , 0.065
# item: ('whipped/sour cream',) , 0.072
# item: ('fruit/vegetable juice',) , 0.072
# item: ('whole milk', 'other vegetables') , 0.075
# item: ('pip fruit',) , 0.076
# item: ('canned beer',) , 0.078
# item: ('newspapers',) , 0.080
# item: ('bottled beer',) , 0.081
# item: ('citrus fruit',) , 0.083
# item: ('pastry',) , 0.089
# item: ('sausage',) , 0.094
# item: ('shopping bags',) , 0.099
# item: ('tropical fruit',) , 0.105
# item: ('root vegetables',) , 0.109
# item: ('bottled water',) , 0.111
# item: ('yogurt',) , 0.140
# item: ('soda',) , 0.174
# item: ('rolls/buns',) , 0.184
# item: ('other vegetables',) , 0.193
# item: ('whole milk',) , 0.256
#
# ------------------------ RULES:
# Rule: ('yogurt',) ==> ('whole milk',) , 0.402
# Rule: ('tropical fruit',) ==> ('whole milk',) , 0.403
# Rule: ('root vegetables',) ==> ('other vegetables',) , 0.435
# Rule: ('root vegetables',) ==> ('whole milk',) , 0.449

# %% [markdown]
# ### Exercice: Create and Product Association Recommender with MovieLens Dataset
# Explain the obtained results and conclusions.

# %%
max2=data
# max2 = max2.loc[max2['user_id'] == 1]
# max2.groupby(['user_id'], sort=False)['rating'].max()
idx = max2.groupby(['user_id'])['rating'].transform(max) == max2['rating']
# max3 = max2[idx].sample(100000)
max3 = max2[idx]
len(max3)
# Out:
# 226570

# %%
# max3['title'] = max3.groupby(['user_id'])['title'].transform(lambda x: ','.join(x))
max_list = max3.groupby('user_id')['title'].apply(list)
len(max_list)
# Out:
# 6040

# %%
max_list2 = [x for x in max_list if len(x) >1]
len(max_list2)
# Out:
# 5984

# %%
# max_list

# %%
# max_list = max3['title'].apply(lambda x: x.split(sep=',')).values.tolist()

# %%
# max_list

# %%
above_mean = data

# %%
len(above_mean)
# Out:
# 1000209

# %%
above_mean['mean_rating']  = above_mean['rating'].groupby(above_mean['user_id']).transform('mean')

# %%
above_mean = above_mean.drop(above_mean[above_mean.rating < above_mean.mean_rating].index)

# %%
above_mean['title'] = above_mean.groupby(['user_id'])['title'].transform(lambda x: ','.join(x))

# %%
above_mean = above_mean[['title']]
# df3 = df2[0:10000]
above_mean.head()
# Out:
#                                                title
# 0  One Flew Over the Cuckoo's Nest (1975),Bug's L...
# 1  One Flew Over the Cuckoo's Nest (1975),Awakeni...
# 2  One Flew Over the Cuckoo's Nest (1975),Christm...
# 3  One Flew Over the Cuckoo's Nest (1975),Erin Br...
# 4  One Flew Over the Cuckoo's Nest (1975),Beauty ...

# %%
# df3['title'] = df3['title'].apply(lambda x: x.split(sep=','))

# %%
# df4 = df3['title'].values.tolist()

# %%
# import pandas as pd
# df2.to_csv('movies_liked.csv')

# %%
# inFile = dataFromFile('movies_liked.csv')

# %%
minSupport = 0.04
minConfidence = 0.5
items, rules =  runApriori(max_list2, minSupport, minConfidence)
printResults(items, rules)
# Out:
# item: ('Game, The (1997)',) , 0.040
# item: ('Big Chill, The (1983)',) , 0.040
# item: ('Bonnie and Clyde (1967)',) , 0.040
# item: ('Platoon (1986)', "Schindler's List (1993)") , 0.040
# item: ('Bridge on the River Kwai, The (1957)', 'Raiders of the Lost Ark (1981)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Willy Wonka and the Chocolate Factory (1971)') , 0.040
# item: ('Lawrence of Arabia (1962)', 'Casablanca (1942)') , 0.040
# item: ('Good Will Hunting (1997)', 'Matrix, The (1999)') , 0.040
# item: ('Glory (1989)', "Schindler's List (1993)") , 0.040
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'Taxi Driver (1976)') , 0.040
# item: ('Monty Python and the Holy Grail (1974)', 'Star Wars: Episode VI - Return of the Jedi (1983)') , 0.040
# item: ("Ferris Bueller's Day Off (1986)", 'Matrix, The (1999)') , 0.040
# item: ('Pulp Fiction (1994)', 'Citizen Kane (1941)') , 0.040
# item: ('Toy Story 2 (1999)', 'Saving Private Ryan (1998)') , 0.040
# item: ('Graduate, The (1967)', 'Raiders of the Lost Ark (1981)') , 0.040
# item: ('Terminator 2: Judgment Day (1991)', 'Forrest Gump (1994)') , 0.040
# item: ('Forrest Gump (1994)', 'Saving Private Ryan (1998)', "Schindler's List (1993)") , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Fargo (1996)', 'Saving Private Ryan (1998)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'GoodFellas (1990)') , 0.040
# item: ('Godfather, The (1972)', 'Citizen Kane (1941)', 'Casablanca (1942)') , 0.040
# item: ('American Beauty (1999)', 'Godfather, The (1972)', 'Matrix, The (1999)') , 0.040
# item: ('American Beauty (1999)', 'Being John Malkovich (1999)', 'Shawshank Redemption, The (1994)') , 0.040
# item: ('Monty Python and the Holy Grail (1974)', 'Godfather, The (1972)', 'Godfather: Part II, The (1974)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)', 'American Beauty (1999)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Aliens (1986)', 'Matrix, The (1999)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)', 'Saving Private Ryan (1998)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Matrix, The (1999)') , 0.040
# item: ('Network (1976)',) , 0.040
# item: ('Rocky (1976)', 'Raiders of the Lost Ark (1981)') , 0.040
# item: ('Raiders of the Lost Ark (1981)', 'Men in Black (1997)') , 0.040
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'Apocalypse Now (1979)') , 0.040
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'Citizen Kane (1941)') , 0.040
# item: ('Aliens (1986)', 'Sixth Sense, The (1999)') , 0.040
# item: ('Shakespeare in Love (1998)', 'Forrest Gump (1994)') , 0.040
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Amadeus (1984)') , 0.040
# item: ('American Beauty (1999)', 'Babe (1995)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Shining, The (1980)') , 0.040
# item: ('Pulp Fiction (1994)', '2001: A Space Odyssey (1968)') , 0.040
# item: ('North by Northwest (1959)', "Schindler's List (1993)") , 0.040
# item: ('Ghostbusters (1984)', 'Sixth Sense, The (1999)') , 0.040
# item: ('Silence of the Lambs, The (1991)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', "Schindler's List (1993)") , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Jurassic Park (1993)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'L.A. Confidential (1997)') , 0.040
# item: ('American Beauty (1999)', "Schindler's List (1993)", 'Sixth Sense, The (1999)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Wizard of Oz, The (1939)') , 0.040
# item: ('Usual Suspects, The (1995)', 'Fargo (1996)', "Schindler's List (1993)") , 0.040
# item: ('American Beauty (1999)', "One Flew Over the Cuckoo's Nest (1975)", 'Fargo (1996)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Die Hard (1988)', 'Matrix, The (1999)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Braveheart (1995)', 'Saving Private Ryan (1998)') , 0.040
# item: ('Grand Day Out, A (1992)',) , 0.040
# item: ('Pulp Fiction (1994)', 'Raising Arizona (1987)') , 0.040
# item: ('Silence of the Lambs, The (1991)', 'Life Is Beautiful (La Vita è bella) (1997)') , 0.040
# item: ('Monty Python and the Holy Grail (1974)', "Monty Python's Life of Brian (1979)") , 0.040
# item: ('Usual Suspects, The (1995)', 'Wizard of Oz, The (1939)') , 0.040
# item: ('Godfather, The (1972)', 'L.A. Confidential (1997)', 'Usual Suspects, The (1995)') , 0.040
# item: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', 'Matrix, The (1999)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Fugitive, The (1993)') , 0.040
# item: ('Monty Python and the Holy Grail (1974)', 'Godfather, The (1972)', 'Raiders of the Lost Ark (1981)') , 0.040
# item: ('Silence of the Lambs, The (1991)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Saving Private Ryan (1998)') , 0.040
# item: ('Pulp Fiction (1994)', 'Saving Private Ryan (1998)', 'Usual Suspects, The (1995)') , 0.040
# item: ('Raiders of the Lost Ark (1981)', 'Die Hard (1988)', 'Matrix, The (1999)') , 0.040
# item: ('Silence of the Lambs, The (1991)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Princess Bride, The (1987)', "Schindler's List (1993)") , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)') , 0.040
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)', 'Terminator, The (1984)') , 0.040
# item: ('Goldfinger (1964)',) , 0.041
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'L.A. Confidential (1997)') , 0.041
# item: ('Dances with Wolves (1990)', 'Saving Private Ryan (1998)') , 0.041
# item: ('Fugitive, The (1993)', 'Godfather, The (1972)') , 0.041
# item: ('Citizen Kane (1941)', 'North by Northwest (1959)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Maltese Falcon, The (1941)') , 0.041
# item: ('Glory (1989)', 'Raiders of the Lost Ark (1981)') , 0.041
# item: ("Schindler's List (1993)", 'Groundhog Day (1993)') , 0.041
# item: ('Pulp Fiction (1994)', 'Christmas Story, A (1983)') , 0.041
# item: ('This Is Spinal Tap (1984)', 'Fargo (1996)') , 0.041
# item: ('American Beauty (1999)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Fargo (1996)') , 0.041
# item: ('Fargo (1996)', 'Pulp Fiction (1994)', 'Reservoir Dogs (1992)') , 0.041
# item: ('Pulp Fiction (1994)', 'Fargo (1996)', 'Godfather: Part II, The (1974)') , 0.041
# item: ('Silence of the Lambs, The (1991)', 'GoodFellas (1990)', 'Fargo (1996)') , 0.041
# item: ('American Beauty (1999)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Braveheart (1995)') , 0.041
# item: ('Usual Suspects, The (1995)', 'Godfather, The (1972)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Wizard of Oz, The (1939)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Shawshank Redemption, The (1994)') , 0.041
# item: ('Shawshank Redemption, The (1994)', "There's Something About Mary (1998)") , 0.041
# item: ('Pulp Fiction (1994)', 'Seven (Se7en) (1995)') , 0.041
# item: ('Usual Suspects, The (1995)', 'Alien (1979)') , 0.041
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Jurassic Park (1993)') , 0.041
# item: ('Godfather, The (1972)', 'Cool Hand Luke (1967)') , 0.041
# item: ('Reservoir Dogs (1992)', 'Matrix, The (1999)') , 0.041
# item: ('Apocalypse Now (1979)', 'Saving Private Ryan (1998)') , 0.041
# item: ('Terminator, The (1984)', 'Godfather: Part II, The (1974)') , 0.041
# item: ('Princess Bride, The (1987)', 'Ghostbusters (1984)') , 0.041
# item: ('American Beauty (1999)', 'Braveheart (1995)', 'Matrix, The (1999)') , 0.041
# item: ('Godfather, The (1972)', 'Casablanca (1942)', "Schindler's List (1993)") , 0.041
# item: ('Silence of the Lambs, The (1991)', 'L.A. Confidential (1997)', 'Shawshank Redemption, The (1994)') , 0.041
# item: ('American Beauty (1999)', 'Usual Suspects, The (1995)', 'GoodFellas (1990)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Back to the Future (1985)', 'Matrix, The (1999)') , 0.041
# item: ('Godfather, The (1972)', 'L.A. Confidential (1997)', 'Pulp Fiction (1994)') , 0.041
# item: ('American Beauty (1999)', 'Star Wars: Episode IV - A New Hope (1977)', 'Being John Malkovich (1999)') , 0.041
# item: ('Godfather, The (1972)', "One Flew Over the Cuckoo's Nest (1975)", "Schindler's List (1993)") , 0.041
# item: ('Fugitive, The (1993)', 'Star Wars: Episode IV - A New Hope (1977)', 'Raiders of the Lost Ark (1981)') , 0.041
# item: ('Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Braveheart (1995)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Usual Suspects, The (1995)', 'Saving Private Ryan (1998)') , 0.041
# item: ('Terminator, The (1984)', 'Raiders of the Lost Ark (1981)', 'Die Hard (1988)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', "Schindler's List (1993)") , 0.041
# item: ('Usual Suspects, The (1995)', 'Apocalypse Now (1979)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'To Kill a Mockingbird (1962)') , 0.041
# item: ('American Beauty (1999)', 'Full Metal Jacket (1987)') , 0.041
# item: ('Graduate, The (1967)', "Schindler's List (1993)") , 0.041
# item: ('Terminator 2: Judgment Day (1991)', 'Godfather: Part II, The (1974)') , 0.041
# item: ('Jurassic Park (1993)', 'Sixth Sense, The (1999)') , 0.041
# item: ('Shawshank Redemption, The (1994)', 'Indiana Jones and the Last Crusade (1989)') , 0.041
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'Being John Malkovich (1999)') , 0.041
# item: ('Princess Bride, The (1987)', 'Die Hard (1988)') , 0.041
# item: ('Casablanca (1942)', 'Psycho (1960)') , 0.041
# item: ('Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)', 'Sixth Sense, The (1999)') , 0.041
# item: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', 'Usual Suspects, The (1995)') , 0.041
# item: ('American Beauty (1999)', 'Raiders of the Lost Ark (1981)', 'Sixth Sense, The (1999)') , 0.041
# item: ('American Beauty (1999)', 'Silence of the Lambs, The (1991)', 'Matrix, The (1999)') , 0.041
# item: ('American Beauty (1999)', 'Usual Suspects, The (1995)', 'Being John Malkovich (1999)') , 0.041
# item: ('Usual Suspects, The (1995)', 'Pulp Fiction (1994)', "Schindler's List (1993)") , 0.041
# item: ('American Beauty (1999)', 'Fargo (1996)', 'Matrix, The (1999)') , 0.041
# item: ('Aliens (1986)', 'Alien (1979)', 'Terminator, The (1984)') , 0.041
# item: ('Silence of the Lambs, The (1991)', "Schindler's List (1993)", 'Usual Suspects, The (1995)') , 0.041
# item: ('Terminator 2: Judgment Day (1991)', 'Terminator, The (1984)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Gladiator (2000)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', "One Flew Over the Cuckoo's Nest (1975)") , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)', 'Raiders of the Lost Ark (1981)') , 0.041
# item: ('Iron Giant, The (1999)',) , 0.041
# item: ('Grosse Pointe Blank (1997)',) , 0.041
# item: ('Rear Window (1954)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.041
# item: ('American Beauty (1999)', 'Twelve Monkeys (1995)') , 0.041
# item: ('Shakespeare in Love (1998)', 'Wizard of Oz, The (1939)') , 0.041
# item: ('Chinatown (1974)', 'Godfather: Part II, The (1974)') , 0.041
# item: ('Raiders of the Lost Ark (1981)', 'Star Trek: The Wrath of Khan (1982)') , 0.041
# item: ('Godfather, The (1972)', 'Stand by Me (1986)') , 0.041
# item: ('Usual Suspects, The (1995)', 'Life Is Beautiful (La Vita è bella) (1997)') , 0.041
# item: ('GoodFellas (1990)', 'Being John Malkovich (1999)') , 0.041
# item: ('American Beauty (1999)', 'Almost Famous (2000)') , 0.041
# item: ('Silence of the Lambs, The (1991)', 'Green Mile, The (1999)') , 0.041
# item: ('Silence of the Lambs, The (1991)', 'Gladiator (2000)') , 0.041
# item: ('Usual Suspects, The (1995)', 'GoodFellas (1990)', 'Fargo (1996)') , 0.041
# item: ('Braveheart (1995)', 'Matrix, The (1999)', 'Sixth Sense, The (1999)') , 0.041
# item: ('Silence of the Lambs, The (1991)', 'Shawshank Redemption, The (1994)', 'Forrest Gump (1994)') , 0.041
# item: ('American Beauty (1999)', 'Godfather, The (1972)', 'L.A. Confidential (1997)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)', 'Raiders of the Lost Ark (1981)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Brazil (1985)') , 0.041
# item: ('Pulp Fiction (1994)', 'Wizard of Oz, The (1939)') , 0.041
# item: ('Good Will Hunting (1997)', 'Fargo (1996)') , 0.041
# item: ('Toy Story (1995)', 'Fargo (1996)') , 0.041
# item: ('E.T. the Extra-Terrestrial (1982)', 'Wizard of Oz, The (1939)') , 0.041
# item: ('Pulp Fiction (1994)', 'Jaws (1975)') , 0.041
# item: ('Raiders of the Lost Ark (1981)', 'Animal House (1978)') , 0.041
# item: ('Annie Hall (1977)', 'Fargo (1996)') , 0.041
# item: ('E.T. the Extra-Terrestrial (1982)', 'Star Wars: Episode VI - Return of the Jedi (1983)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Good Will Hunting (1997)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Blade Runner (1982)') , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)', 'Usual Suspects, The (1995)') , 0.041
# item: ('On the Waterfront (1954)',) , 0.041
# item: ('True Lies (1994)',) , 0.041
# item: ('Silence of the Lambs, The (1991)', 'Amadeus (1984)') , 0.041
# item: ('Godfather, The (1972)', 'Gladiator (2000)') , 0.041
# item: ('Maltese Falcon, The (1941)', 'Godfather, The (1972)') , 0.041
# item: ('Lethal Weapon (1987)', 'Raiders of the Lost Ark (1981)') , 0.041
# item: ('Godfather, The (1972)', 'M*A*S*H (1970)') , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Airplane! (1980)') , 0.041
# item: ('Shawshank Redemption, The (1994)', 'Apocalypse Now (1979)') , 0.041
# item: ('Silence of the Lambs, The (1991)', 'Back to the Future (1985)') , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Citizen Kane (1941)') , 0.041
# item: ('Hunt for Red October, The (1990)', 'Braveheart (1995)') , 0.041
# item: ('Terminator 2: Judgment Day (1991)', 'Terminator, The (1984)', 'Matrix, The (1999)') , 0.041
# item: ('Fargo (1996)', 'Pulp Fiction (1994)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.041
# item: ('Godfather, The (1972)', 'Godfather: Part II, The (1974)', 'Blade Runner (1982)') , 0.041
# item: ('Godfather, The (1972)', 'Citizen Kane (1941)', 'Godfather: Part II, The (1974)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Raiders of the Lost Ark (1981)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.041
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)', 'Braveheart (1995)') , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Braveheart (1995)') , 0.041
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Godfather: Part II, The (1974)', 'Raiders of the Lost Ark (1981)') , 0.041
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)') , 0.041
# item: ('Edward Scissorhands (1990)',) , 0.042
# item: ('Aliens (1986)', 'Fargo (1996)') , 0.042
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Fargo (1996)') , 0.042
# item: ('Citizen Kane (1941)', 'Wizard of Oz, The (1939)') , 0.042
# item: ('GoodFellas (1990)', 'Sixth Sense, The (1999)') , 0.042
# item: ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 'Apocalypse Now (1979)') , 0.042
# item: ('Jaws (1975)', 'Terminator, The (1984)') , 0.042
# item: ('American Beauty (1999)', 'Godfather, The (1972)', "One Flew Over the Cuckoo's Nest (1975)") , 0.042
# item: ('Usual Suspects, The (1995)', 'Matrix, The (1999)', 'Sixth Sense, The (1999)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Terminator, The (1984)') , 0.042
# item: ('Shawshank Redemption, The (1994)', 'Matrix, The (1999)', "Schindler's List (1993)") , 0.042
# item: ('Princess Bride, The (1987)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Shawshank Redemption, The (1994)') , 0.042
# item: ('Monty Python and the Holy Grail (1974)', 'Star Wars: Episode IV - A New Hope (1977)', 'Matrix, The (1999)') , 0.042
# item: ('Silence of the Lambs, The (1991)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Pulp Fiction (1994)') , 0.042
# item: ('American Beauty (1999)', 'Silence of the Lambs, The (1991)', 'GoodFellas (1990)') , 0.042
# item: ('Raiders of the Lost Ark (1981)', 'Matrix, The (1999)', 'Indiana Jones and the Last Crusade (1989)') , 0.042
# item: ('Usual Suspects, The (1995)', 'Terminator, The (1984)') , 0.042
# item: ('Back to the Future (1985)', 'Toy Story (1995)') , 0.042
# item: ('American Beauty (1999)', 'Rear Window (1954)') , 0.042
# item: ('Fargo (1996)', 'Fight Club (1999)') , 0.042
# item: ('Sling Blade (1996)', "Schindler's List (1993)") , 0.042
# item: ('Godfather, The (1972)', 'Back to the Future (1985)') , 0.042
# item: ('American Beauty (1999)', 'Seven (Se7en) (1995)') , 0.042
# item: ('Shawshank Redemption, The (1994)', 'To Kill a Mockingbird (1962)') , 0.042
# item: ('Jaws (1975)', 'Aliens (1986)') , 0.042
# item: ('Godfather, The (1972)', 'Animal House (1978)') , 0.042
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'Sixth Sense, The (1999)') , 0.042
# item: ('Godfather, The (1972)', 'This Is Spinal Tap (1984)') , 0.042
# item: ('American Beauty (1999)', 'Raiders of the Lost Ark (1981)', 'Fargo (1996)') , 0.042
# item: ('American Beauty (1999)', 'Godfather, The (1972)', 'GoodFellas (1990)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Aliens (1986)', 'Star Wars: Episode VI - Return of the Jedi (1983)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Trek: The Wrath of Khan (1982)') , 0.042
# item: ('Gattaca (1997)',) , 0.042
# item: ('Truman Show, The (1998)',) , 0.042
# item: ('Trainspotting (1996)',) , 0.042
# item: ('Swingers (1996)',) , 0.042
# item: ('Wallace & Gromit: The Best of Aardman Animation (1996)',) , 0.042
# item: ('Graduate, The (1967)', 'Fargo (1996)') , 0.042
# item: ('Aliens (1986)', "Schindler's List (1993)") , 0.042
# item: ('Close Encounters of the Third Kind (1977)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'M*A*S*H (1970)') , 0.042
# item: ('Clockwork Orange, A (1971)', 'Pulp Fiction (1994)') , 0.042
# item: ('American Beauty (1999)', "There's Something About Mary (1998)") , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Graduate, The (1967)') , 0.042
# item: ('L.A. Confidential (1997)', 'Reservoir Dogs (1992)') , 0.042
# item: ('Silence of the Lambs, The (1991)', '2001: A Space Odyssey (1968)') , 0.042
# item: ('Bridge on the River Kwai, The (1957)', "Schindler's List (1993)") , 0.042
# item: ('American Beauty (1999)', 'Ghostbusters (1984)') , 0.042
# item: ('Casablanca (1942)', 'To Kill a Mockingbird (1962)') , 0.042
# item: ('When Harry Met Sally... (1989)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Hunt for Red October, The (1990)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.042
# item: ('Usual Suspects, The (1995)', 'Good Will Hunting (1997)') , 0.042
# item: ('Fargo (1996)', 'Christmas Story, A (1983)') , 0.042
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Blade Runner (1982)') , 0.042
# item: ('Silence of the Lambs, The (1991)', 'Matrix, The (1999)', 'Usual Suspects, The (1995)') , 0.042
# item: ('Aliens (1986)', 'Raiders of the Lost Ark (1981)', 'Matrix, The (1999)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') , 0.042
# item: ('Right Stuff, The (1983)',) , 0.042
# item: ('Speed (1994)',) , 0.042
# item: ('Matrix, The (1999)', 'Groundhog Day (1993)') , 0.042
# item: ('Casablanca (1942)', 'Sixth Sense, The (1999)') , 0.042
# item: ('Fargo (1996)', 'Groundhog Day (1993)') , 0.042
# item: ('Princess Bride, The (1987)', 'Stand by Me (1986)') , 0.042
# item: ('Fugitive, The (1993)', "Schindler's List (1993)") , 0.042
# item: ('Aliens (1986)', 'Die Hard (1988)') , 0.042
# item: ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 'Saving Private Ryan (1998)') , 0.042
# item: ('American Beauty (1999)', 'Chinatown (1974)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Chinatown (1974)') , 0.042
# item: ('Apocalypse Now (1979)', 'Godfather: Part II, The (1974)') , 0.042
# item: ('Hunt for Red October, The (1990)', 'Matrix, The (1999)') , 0.042
# item: ('American Beauty (1999)', 'Princess Bride, The (1987)', 'Shawshank Redemption, The (1994)') , 0.042
# item: ('Silence of the Lambs, The (1991)', 'GoodFellas (1990)', 'Shawshank Redemption, The (1994)') , 0.042
# item: ('Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)', 'Shawshank Redemption, The (1994)') , 0.042
# item: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)') , 0.042
# item: ('Godfather, The (1972)', 'Fargo (1996)', 'Saving Private Ryan (1998)') , 0.042
# item: ('Godfather, The (1972)', 'Terminator, The (1984)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Braveheart (1995)', 'Saving Private Ryan (1998)', 'Sixth Sense, The (1999)') , 0.042
# item: ('American Beauty (1999)', 'L.A. Confidential (1997)', "Schindler's List (1993)") , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Princess Bride, The (1987)') , 0.042
# item: ('Princess Bride, The (1987)', 'Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)') , 0.042
# item: ('Indiana Jones and the Temple of Doom (1984)',) , 0.042
# item: ('Godfather, The (1972)', 'Boat, The (Das Boot) (1981)') , 0.042
# item: ('North by Northwest (1959)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.042
# item: ('Monty Python and the Holy Grail (1974)', 'Godfather: Part II, The (1974)') , 0.042
# item: ('Shakespeare in Love (1998)', 'Toy Story (1995)') , 0.042
# item: ('Monty Python and the Holy Grail (1974)', 'L.A. Confidential (1997)') , 0.042
# item: ('Raiders of the Lost Ark (1981)', 'Raising Arizona (1987)') , 0.042
# item: ('Silence of the Lambs, The (1991)', 'Apocalypse Now (1979)') , 0.042
# item: ('Christmas Story, A (1983)', "Schindler's List (1993)") , 0.042
# item: ('Princess Bride, The (1987)', 'When Harry Met Sally... (1989)') , 0.042
# item: ('Pulp Fiction (1994)', 'Sling Blade (1996)') , 0.042
# item: ("Schindler's List (1993)", 'Psycho (1960)') , 0.042
# item: ('Usual Suspects, The (1995)', 'Forrest Gump (1994)') , 0.042
# item: ('Monty Python and the Holy Grail (1974)', 'Casablanca (1942)') , 0.042
# item: ('Back to the Future (1985)', 'Forrest Gump (1994)') , 0.042
# item: ('Godfather, The (1972)', 'Fargo (1996)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.042
# item: ('Raiders of the Lost Ark (1981)', 'Braveheart (1995)', 'Shawshank Redemption, The (1994)') , 0.042
# item: ('Sixth Sense, The (1999)', 'Saving Private Ryan (1998)', "Schindler's List (1993)") , 0.042
# item: ('Princess Bride, The (1987)', 'Monty Python and the Holy Grail (1974)', 'Star Wars: Episode IV - A New Hope (1977)') , 0.042
# item: ('Pulp Fiction (1994)', 'Reservoir Dogs (1992)', 'Usual Suspects, The (1995)') , 0.042
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Matrix, The (1999)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Moonstruck (1987)',) , 0.042
# item: ('Last of the Mohicans, The (1992)',) , 0.042
# item: ('Dances with Wolves (1990)', "Schindler's List (1993)") , 0.042
# item: ('American Beauty (1999)', 'When Harry Met Sally... (1989)') , 0.042
# item: ('Princess Bride, The (1987)', 'Godfather: Part II, The (1974)') , 0.042
# item: ('Godfather, The (1972)', 'Raising Arizona (1987)') , 0.042
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Groundhog Day (1993)') , 0.042
# item: ('American Beauty (1999)', 'South Park: Bigger, Longer and Uncut (1999)') , 0.042
# item: ('Rear Window (1954)', 'Vertigo (1958)') , 0.042
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Shawshank Redemption, The (1994)', 'Braveheart (1995)') , 0.042
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Fargo (1996)') , 0.042
# item: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', 'Pulp Fiction (1994)') , 0.042
# item: ('Terminator 2: Judgment Day (1991)', 'Terminator, The (1984)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('American Beauty (1999)', 'Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Aliens (1986)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Matrix, The (1999)', 'Raiders of the Lost Ark (1981)') , 0.042
# item: ('Like Water for Chocolate (Como agua para chocolate) (1992)',) , 0.043
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Die Hard (1988)') , 0.043
# item: ('Raiders of the Lost Ark (1981)', 'Reservoir Dogs (1992)') , 0.043
# item: ('Jaws (1975)', 'Braveheart (1995)') , 0.043
# item: ('Chinatown (1974)', 'Blade Runner (1982)') , 0.043
# item: ('Glory (1989)', 'Star Wars: Episode IV - A New Hope (1977)') , 0.043
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode I - The Phantom Menace (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Rocky (1976)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Life Is Beautiful (La Vita è bella) (1997)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Shawshank Redemption, The (1994)', 'Matrix, The (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Back to the Future (1985)', 'Star Wars: Episode VI - Return of the Jedi (1983)') , 0.043
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Alien (1979)', 'Matrix, The (1999)') , 0.043
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)', 'Blade Runner (1982)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'L.A. Confidential (1997)', 'Usual Suspects, The (1995)') , 0.043
# item: ('Fargo (1996)', 'Psycho (1960)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Lawrence of Arabia (1962)') , 0.043
# item: ('Usual Suspects, The (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.043
# item: ('Pulp Fiction (1994)', 'Toy Story (1995)') , 0.043
# item: ('Twelve Monkeys (1995)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.043
# item: ('Raiders of the Lost Ark (1981)', 'Psycho (1960)') , 0.043
# item: ('Saving Private Ryan (1998)', 'Indiana Jones and the Last Crusade (1989)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)') , 0.043
# item: ('Godfather, The (1972)', "One Flew Over the Cuckoo's Nest (1975)", 'Fargo (1996)') , 0.043
# item: ('Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)', 'Godfather, The (1972)') , 0.043
# item: ('Pulp Fiction (1994)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Usual Suspects, The (1995)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Terminator, The (1984)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', "Schindler's List (1993)") , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Alien (1979)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Big Sleep, The (1946)',) , 0.043
# item: ('Nightmare Before Christmas, The (1993)',) , 0.043
# item: ('Full Metal Jacket (1987)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.043
# item: ('Jaws (1975)', 'Matrix, The (1999)') , 0.043
# item: ('Toy Story 2 (1999)', "Schindler's List (1993)") , 0.043
# item: ('Monty Python and the Holy Grail (1974)', 'Braveheart (1995)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.043
# item: ('Terminator 2: Judgment Day (1991)', 'Blade Runner (1982)') , 0.043
# item: ('Shakespeare in Love (1998)', 'Braveheart (1995)') , 0.043
# item: ('Aliens (1986)', 'Raiders of the Lost Ark (1981)', 'Alien (1979)') , 0.043
# item: ('Godfather, The (1972)', 'L.A. Confidential (1997)', 'Fargo (1996)') , 0.043
# item: ('Godfather, The (1972)', 'Raiders of the Lost Ark (1981)', 'Alien (1979)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Pulp Fiction (1994)', "Schindler's List (1993)") , 0.043
# item: ('Back to the Future (1985)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Usual Suspects, The (1995)', 'Fargo (1996)') , 0.043
# item: ('American Beauty (1999)', 'Fargo (1996)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Pulp Fiction (1994)', 'Raiders of the Lost Ark (1981)', 'Usual Suspects, The (1995)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Shawshank Redemption, The (1994)', 'Fargo (1996)') , 0.043
# item: ('Godfather, The (1972)', 'Raiders of the Lost Ark (1981)', 'Usual Suspects, The (1995)') , 0.043
# item: ('American Beauty (1999)', 'Silence of the Lambs, The (1991)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.043
# item: ('Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Matrix, The (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', "Schindler's List (1993)") , 0.043
# item: ('Dark City (1998)',) , 0.043
# item: ('Wizard of Oz, The (1939)', 'Godfather: Part II, The (1974)') , 0.043
# item: ('Godfather, The (1972)', 'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)') , 0.043
# item: ('Terminator 2: Judgment Day (1991)', 'Jurassic Park (1993)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'When Harry Met Sally... (1989)') , 0.043
# item: ('Being John Malkovich (1999)', 'Blade Runner (1982)') , 0.043
# item: ('American Beauty (1999)', 'Raising Arizona (1987)') , 0.043
# item: ('Dances with Wolves (1990)', 'Shawshank Redemption, The (1994)') , 0.043
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Reservoir Dogs (1992)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Die Hard (1988)') , 0.043
# item: ('Sixth Sense, The (1999)', 'Blade Runner (1982)') , 0.043
# item: ('Godfather, The (1972)', 'Shawshank Redemption, The (1994)', 'Fargo (1996)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Silence of the Lambs, The (1991)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Alien (1979)', 'Blade Runner (1982)') , 0.043
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Terminator, The (1984)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Aliens (1986)', 'Terminator, The (1984)') , 0.043
# item: ('Pulp Fiction (1994)', 'Being John Malkovich (1999)', 'Fargo (1996)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Silence of the Lambs, The (1991)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Pulp Fiction (1994)', 'Raiders of the Lost Ark (1981)', 'Fargo (1996)') , 0.043
# item: ('Terminator, The (1984)', 'Raiders of the Lost Ark (1981)', 'Matrix, The (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Pulp Fiction (1994)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Usual Suspects, The (1995)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Terminator 2: Judgment Day (1991)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Terminator, The (1984)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Austin Powers: The Spy Who Shagged Me (1999)',) , 0.043
# item: ('Three Kings (1999)',) , 0.043
# item: ('Four Weddings and a Funeral (1994)',) , 0.043
# item: ('Batman (1989)',) , 0.043
# item: ('Hunt for Red October, The (1990)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Green Mile, The (1999)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Terminator, The (1984)', 'Fargo (1996)') , 0.043
# item: ('E.T. the Extra-Terrestrial (1982)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Aliens (1986)', 'Shawshank Redemption, The (1994)') , 0.043
# item: ('2001: A Space Odyssey (1968)', 'Casablanca (1942)') , 0.043
# item: ('L.A. Confidential (1997)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.043
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'Wizard of Oz, The (1939)') , 0.043
# item: ('E.T. the Extra-Terrestrial (1982)', 'Matrix, The (1999)') , 0.043
# item: ('Wizard of Oz, The (1939)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Usual Suspects, The (1995)', 'Silence of the Lambs, The (1991)') , 0.043
# item: ('Pulp Fiction (1994)', 'Godfather, The (1972)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Godfather, The (1972)', 'Usual Suspects, The (1995)') , 0.043
# item: ('Pulp Fiction (1994)', 'Silence of the Lambs, The (1991)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Aliens (1986)') , 0.043
# item: ('Pulp Fiction (1994)', 'Raiders of the Lost Ark (1981)', 'Shawshank Redemption, The (1994)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Die Hard (1988)') , 0.043
# item: ('My Fair Lady (1964)',) , 0.043
# item: ('Heat (1995)',) , 0.043
# item: ('Gandhi (1982)',) , 0.043
# item: ('Princess Bride, The (1987)', 'Aliens (1986)') , 0.043
# item: ('E.T. the Extra-Terrestrial (1982)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Fight Club (1999)') , 0.043
# item: ('Die Hard (1988)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Back to the Future (1985)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Amadeus (1984)', 'Fargo (1996)') , 0.043
# item: ('Sting, The (1973)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Shawshank Redemption, The (1994)', 'Braveheart (1995)') , 0.043
# item: ('Saving Private Ryan (1998)', 'Sixth Sense, The (1999)', 'Matrix, The (1999)') , 0.043
# item: ('Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Monty Python and the Holy Grail (1974)') , 0.043
# item: ('Silence of the Lambs, The (1991)', 'Braveheart (1995)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)') , 0.043
# item: ('Godfather, The (1972)', 'Jaws (1975)', 'Godfather: Part II, The (1974)') , 0.043
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Saving Private Ryan (1998)', 'Sixth Sense, The (1999)') , 0.043
# item: ('Princess Bride, The (1987)', 'Godfather, The (1972)', 'Star Wars: Episode IV - A New Hope (1977)') , 0.043
# item: ('American Beauty (1999)', 'Pulp Fiction (1994)', 'Raiders of the Lost Ark (1981)') , 0.043
# item: ('Manhattan (1979)',) , 0.044
# item: ('Blood Simple (1984)',) , 0.044
# item: ('Taxi Driver (1976)', 'Godfather: Part II, The (1974)') , 0.044
# item: ('Wizard of Oz, The (1939)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Terminator, The (1984)', "Schindler's List (1993)") , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'This Is Spinal Tap (1984)') , 0.044
# item: ('Terminator 2: Judgment Day (1991)', 'Usual Suspects, The (1995)') , 0.044
# item: ('Terminator 2: Judgment Day (1991)', 'Back to the Future (1985)') , 0.044
# item: ('Being John Malkovich (1999)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.044
# item: ('Jurassic Park (1993)', 'Braveheart (1995)') , 0.044
# item: ('Full Metal Jacket (1987)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.044
# item: ('Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)', 'Fargo (1996)') , 0.044
# item: ('Godfather, The (1972)', "Schindler's List (1993)", 'Pulp Fiction (1994)') , 0.044
# item: ('American Beauty (1999)', 'Silence of the Lambs, The (1991)', 'L.A. Confidential (1997)') , 0.044
# item: ('Silence of the Lambs, The (1991)', 'Saving Private Ryan (1998)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Shawshank Redemption, The (1994)', 'Braveheart (1995)', 'Matrix, The (1999)') , 0.044
# item: ('Princess Bride, The (1987)', 'Star Wars: Episode IV - A New Hope (1977)', 'American Beauty (1999)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Matrix, The (1999)', "Schindler's List (1993)") , 0.044
# item: ('Raiders of the Lost Ark (1981)', 'Sixth Sense, The (1999)', 'Shawshank Redemption, The (1994)') , 0.044
# item: ('Silence of the Lambs, The (1991)', 'L.A. Confidential (1997)', 'Fargo (1996)') , 0.044
# item: ('Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Star Wars: Episode VI - Return of the Jedi (1983)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Little Mermaid, The (1989)',) , 0.044
# item: ('Predator (1987)',) , 0.044
# item: ('Amadeus (1984)', 'Raiders of the Lost Ark (1981)') , 0.044
# item: ('Monty Python and the Holy Grail (1974)', 'Sixth Sense, The (1999)') , 0.044
# item: ('To Kill a Mockingbird (1962)', "Schindler's List (1993)") , 0.044
# item: ('American Beauty (1999)', 'Pulp Fiction (1994)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.044
# item: ('Shawshank Redemption, The (1994)', 'Saving Private Ryan (1998)', 'Matrix, The (1999)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)', 'Terminator 2: Judgment Day (1991)') , 0.044
# item: ('When Harry Met Sally... (1989)', 'Shawshank Redemption, The (1994)') , 0.044
# item: ('Silence of the Lambs, The (1991)', 'Fight Club (1999)') , 0.044
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Toy Story 2 (1999)') , 0.044
# item: ('Fargo (1996)', 'Forrest Gump (1994)') , 0.044
# item: ('American Beauty (1999)', 'Psycho (1960)') , 0.044
# item: ('North by Northwest (1959)', 'Fargo (1996)') , 0.044
# item: ('Godfather, The (1972)', 'Young Frankenstein (1974)') , 0.044
# item: ('Shawshank Redemption, The (1994)', "Ferris Bueller's Day Off (1986)") , 0.044
# item: ('American Beauty (1999)', 'Shawshank Redemption, The (1994)', 'L.A. Confidential (1997)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Godfather, The (1972)', 'Alien (1979)', 'Godfather: Part II, The (1974)') , 0.044
# item: ('Godfather, The (1972)', 'Braveheart (1995)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Usual Suspects, The (1995)', 'GoodFellas (1990)', 'Pulp Fiction (1994)') , 0.044
# item: ('American Beauty (1999)', 'Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Star Trek: First Contact (1996)',) , 0.044
# item: ('Producers, The (1968)',) , 0.044
# item: ('Pulp Fiction (1994)', 'Taxi Driver (1976)') , 0.044
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', "Ferris Bueller's Day Off (1986)") , 0.044
# item: ('Toy Story 2 (1999)', 'Matrix, The (1999)') , 0.044
# item: ('E.T. the Extra-Terrestrial (1982)', 'Back to the Future (1985)') , 0.044
# item: ('American Beauty (1999)', 'Airplane! (1980)') , 0.044
# item: ('Shawshank Redemption, The (1994)', 'Die Hard (1988)') , 0.044
# item: ('Terminator 2: Judgment Day (1991)', 'Fargo (1996)') , 0.044
# item: ('Pulp Fiction (1994)', 'Godfather, The (1972)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.044
# item: ('Godfather, The (1972)', 'Raiders of the Lost Ark (1981)', 'Braveheart (1995)') , 0.044
# item: ('American Beauty (1999)', 'GoodFellas (1990)', 'Shawshank Redemption, The (1994)') , 0.044
# item: ('Shawshank Redemption, The (1994)', 'Fargo (1996)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Godfather, The (1972)', 'GoodFellas (1990)', 'Fargo (1996)') , 0.044
# item: ('American Beauty (1999)', 'Raiders of the Lost Ark (1981)', "Schindler's List (1993)") , 0.044
# item: ('Raiders of the Lost Ark (1981)', 'Matrix, The (1999)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Fight Club (1999)') , 0.044
# item: ('Toy Story 2 (1999)', 'Shawshank Redemption, The (1994)') , 0.044
# item: ('Raiders of the Lost Ark (1981)', 'Blues Brothers, The (1980)') , 0.044
# item: ('Rear Window (1954)', 'Raiders of the Lost Ark (1981)') , 0.044
# item: ('Raising Arizona (1987)', 'Fargo (1996)') , 0.044
# item: ('Shawshank Redemption, The (1994)', 'Blade Runner (1982)') , 0.044
# item: ('African Queen, The (1951)', 'Casablanca (1942)') , 0.044
# item: ('Amadeus (1984)', 'Shawshank Redemption, The (1994)') , 0.044
# item: ('Rear Window (1954)', 'Fargo (1996)') , 0.044
# item: ('Monty Python and the Holy Grail (1974)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)') , 0.044
# item: ('Princess Bride, The (1987)', 'Forrest Gump (1994)') , 0.044
# item: ('Monty Python and the Holy Grail (1974)', "One Flew Over the Cuckoo's Nest (1975)") , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Pulp Fiction (1994)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Raiders of the Lost Ark (1981)', 'Forrest Gump (1994)') , 0.044
# item: ('Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)', 'Matrix, The (1999)') , 0.044
# item: ('Sixth Sense, The (1999)', 'Groundhog Day (1993)') , 0.044
# item: ('Jurassic Park (1993)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Raiders of the Lost Ark (1981)', 'Groundhog Day (1993)') , 0.044
# item: ("One Flew Over the Cuckoo's Nest (1975)", 'L.A. Confidential (1997)') , 0.044
# item: ('North by Northwest (1959)', 'Raiders of the Lost Ark (1981)') , 0.044
# item: ('2001: A Space Odyssey (1968)', "Schindler's List (1993)") , 0.044
# item: ('Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)', 'Saving Private Ryan (1998)') , 0.044
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Godfather: Part II, The (1974)') , 0.044
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Silence of the Lambs, The (1991)', "Schindler's List (1993)") , 0.044
# item: ('Godfather, The (1972)', 'Fargo (1996)', "Schindler's List (1993)") , 0.044
# item: ('Godfather, The (1972)', 'Braveheart (1995)', 'Godfather: Part II, The (1974)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Usual Suspects, The (1995)', 'Matrix, The (1999)') , 0.044
# item: ('Monty Python and the Holy Grail (1974)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)') , 0.044
# item: ('Silence of the Lambs, The (1991)', 'Matrix, The (1999)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Silence of the Lambs, The (1991)', 'Godfather, The (1972)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') , 0.044
# item: ('American Beauty (1999)', 'Usual Suspects, The (1995)', 'Raiders of the Lost Ark (1981)') , 0.044
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Silence of the Lambs, The (1991)', 'Matrix, The (1999)') , 0.044
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Terminator 2: Judgment Day (1991)') , 0.044
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Aliens (1986)', 'Alien (1979)') , 0.044
# item: ('American Beauty (1999)', 'Star Wars: Episode IV - A New Hope (1977)', 'Sixth Sense, The (1999)') , 0.044
# item: ('Good Will Hunting (1997)', 'Sixth Sense, The (1999)') , 0.045
# item: ('Jaws (1975)', 'Shawshank Redemption, The (1994)') , 0.045
# item: ('Fugitive, The (1993)', 'Terminator 2: Judgment Day (1991)') , 0.045
# item: ('Fargo (1996)', 'Life Is Beautiful (La Vita è bella) (1997)') , 0.045
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'Bridge on the River Kwai, The (1957)') , 0.045
# item: ('Terminator 2: Judgment Day (1991)', 'Die Hard (1988)') , 0.045
# item: ('Usual Suspects, The (1995)', 'Star Wars: Episode VI - Return of the Jedi (1983)') , 0.045
# item: ('American Beauty (1999)', 'Pulp Fiction (1994)', 'Matrix, The (1999)') , 0.045
# item: ('Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Saving Private Ryan (1998)') , 0.045
# item: ('Pulp Fiction (1994)', 'GoodFellas (1990)', 'Silence of the Lambs, The (1991)') , 0.045
# item: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Jaws (1975)', 'Raiders of the Lost Ark (1981)') , 0.045
# item: ('Star Wars: Episode IV - A New Hope (1977)', 'E.T. the Extra-Terrestrial (1982)', 'Raiders of the Lost Ark (1981)') , 0.045
# ...
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Raiders of the Lost Ark (1981)',) , 0.843
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Aliens (1986)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.844
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.844
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Trek: The Wrath of Khan (1982)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.845
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Terminator, The (1984)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.845
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Braveheart (1995)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.845
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Raiders of the Lost Ark (1981)',) , 0.845
# Rule: ('Silence of the Lambs, The (1991)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.846
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.849
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Jaws (1975)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.850
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Aliens (1986)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.850
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Terminator, The (1984)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.851
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Terminator, The (1984)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.851
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Wizard of Oz, The (1939)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.852
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Braveheart (1995)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.853
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.855
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Jurassic Park (1993)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.855
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Shawshank Redemption, The (1994)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.855
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.856
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', "Schindler's List (1993)") ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.856
# Rule: ('Princess Bride, The (1987)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.858
# Rule: ('Godfather: Part II, The (1974)',) ==> ('Godfather, The (1972)',) , 0.859
# Rule: ('Usual Suspects, The (1995)', 'Raiders of the Lost Ark (1981)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.860
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Saving Private Ryan (1998)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.860
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.861
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Shawshank Redemption, The (1994)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.862
# Rule: ('Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)', 'Star Wars: Episode V - The Empire Strikes Back (1980)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.863
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Princess Bride, The (1987)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.863
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Die Hard (1988)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.863
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.864
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Raiders of the Lost Ark (1981)',) , 0.864
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Saving Private Ryan (1998)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.864
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.865
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Pulp Fiction (1994)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.866
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Raiders of the Lost Ark (1981)',) , 0.866
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Aliens (1986)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.866
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Terminator, The (1984)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.867
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', "Schindler's List (1993)") ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.869
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Raiders of the Lost Ark (1981)',) , 0.869
# Rule: ('Godfather, The (1972)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.870
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Alien (1979)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.871
# Rule: ('Godfather, The (1972)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.873
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Saving Private Ryan (1998)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.873
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Braveheart (1995)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.876
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.876
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.877
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Matrix, The (1999)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.878
# Rule: ('Princess Bride, The (1987)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.878
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.878
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Shawshank Redemption, The (1994)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.880
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Aliens (1986)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.881
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.881
# Rule: ('Silence of the Lambs, The (1991)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.882
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.882
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.882
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.884
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)', 'Matrix, The (1999)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.885
# Rule: ('American Beauty (1999)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.885
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.886
# Rule: ('Princess Bride, The (1987)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.887
# Rule: ('Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.888
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Terminator 2: Judgment Day (1991)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.888
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Terminator 2: Judgment Day (1991)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.890
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Braveheart (1995)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.890
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Indiana Jones and the Last Crusade (1989)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.890
# Rule: ('L.A. Confidential (1997)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.890
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Saving Private Ryan (1998)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.892
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Sixth Sense, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.893
# Rule: ('Citizen Kane (1941)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.899
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Matrix, The (1999)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.900
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Saving Private Ryan (1998)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.901
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.901
# Rule: ('Fargo (1996)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.902
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Star Wars: Episode VI - Return of the Jedi (1983)') ==> ('Star Wars: Episode V - The Empire Strikes Back (1980)',) , 0.903
# Rule: ('GoodFellas (1990)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.904
# Rule: ('Godfather: Part II, The (1974)', "Schindler's List (1993)") ==> ('Godfather, The (1972)',) , 0.906
# Rule: ('Casablanca (1942)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.906
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Godfather, The (1972)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.906
# Rule: ('Raiders of the Lost Ark (1981)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.910
# Rule: ('Monty Python and the Holy Grail (1974)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.910
# Rule: ('Shawshank Redemption, The (1994)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.912
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Braveheart (1995)') ==> ('Star Wars: Episode IV - A New Hope (1977)',) , 0.914
# Rule: ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.919
# Rule: ('Alien (1979)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.920
# Rule: ("One Flew Over the Cuckoo's Nest (1975)", 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.920
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Raiders of the Lost Ark (1981)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.920
# Rule: ('Godfather: Part II, The (1974)', 'Blade Runner (1982)') ==> ('Godfather, The (1972)',) , 0.922
# Rule: ('Pulp Fiction (1994)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.922
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.923
# Rule: ('Saving Private Ryan (1998)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.924
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.925
# Rule: ('Usual Suspects, The (1995)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.927
# Rule: ('Matrix, The (1999)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.927
# Rule: ('Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raiders of the Lost Ark (1981)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.932
# Rule: ('Braveheart (1995)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.933
# Rule: ('Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.934
# Rule: ('Jaws (1975)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.935
# Rule: ('Monty Python and the Holy Grail (1974)', 'Godfather: Part II, The (1974)') ==> ('Godfather, The (1972)',) , 0.949
